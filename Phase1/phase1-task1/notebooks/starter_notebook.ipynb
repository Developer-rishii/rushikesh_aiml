# %% [markdown]
# # Task 1 — Starter Notebook
# Day 1: prove the pipeline works end-to-end. All real logic lives in `src/` — this notebook only *calls* it (notebook -> module discipline).

# %%
import sys, pathlib
sys.path.append(str(pathlib.Path.cwd().parent))
from src import data_ingestion, data_split, smoke_test

# %%
df = data_ingestion.ingest()
df.head()

# %%
train_df, val_df, test_df = data_split.run()
len(train_df), len(val_df), len(test_df)

# %%
metrics = smoke_test.run_smoke_test()
metrics

# %% [markdown]
# ## Reproducibility check
# Re-running this notebook top-to-bottom (or `python -m src.run_pipeline`) should reproduce the exact same split sizes and baseline metrics, since `SEED=42` is fixed in `configs/config.py`.
