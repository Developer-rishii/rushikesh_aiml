# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("data/synthetic_students.csv")

# %%
df.head()
# Out:
#   student_id level_id  score  time_spent_minutes  passed   timestamp
# 0   STU_0001  LVL_008     39                   7   False  2023-02-27
# 1   STU_0001  LVL_002     90                  18    True  2023-02-28
# 2   STU_0001  LVL_048     58                   8   False  2023-03-01
# 3   STU_0001  LVL_018     84                  38    True  2023-03-02
# 4   STU_0001  LVL_016     59                  21   False  2023-03-03

# %%
df.shape
# Out:
# (15140, 6)

# %%
df.isnull().sum()
# Out:
# student_id            0
# level_id              0
# score                 0
# time_spent_minutes    0
# passed                0
# timestamp             0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.to_csv("data/student_progress.csv", index= False)
