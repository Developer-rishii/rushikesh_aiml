# %% [markdown]
# # PlaceMux Explainability Module - Data Exploration
#
# This notebook explores the generated dummy datasets.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_students = pd.read_csv('../data/students.csv')
df_jobs = pd.read_csv('../data/jobs.csv')
df_matches = pd.read_csv('../data/matches.csv')

print(f"Students: {len(df_students)}")
print(f"Jobs: {len(df_jobs)}")
print(f"Matches: {len(df_matches)}")
# Out:
# Students: 2000
# Jobs: 500
# Matches: 3000

# %%
df_matches.head()
# Out:
#    student_id  job_id  match_score  matched
# 0         648     574           48        0
# 1        1661     969           53        0
# 2         291     816           50        0
# 3         665     702           37        0
# 4         186     523           32        0

# %%
plt.hist(df_matches['match_score'], bins=20)
plt.title('Distribution of Match Scores')
plt.xlabel('Match Score')
plt.ylabel('Frequency')
plt.show()
